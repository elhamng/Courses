# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
out_side=['G1','G2','G1','G2','G1','G2']
inside=[1,2,3,1,2,3]
hier_index=list(zip(out_side,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            codes=[[0, 1, 0, 1, 0, 1], [0, 1, 2, 0, 1, 2]])

# %%
df=pd.DataFrame(randn(6,2),hier_index,['A','B'])
df
# Out:
#              A         B
# G1 1 -1.576038  1.230317
# G2 2  1.536682  0.438089
# G1 3 -0.752680  1.403316
# G2 1  0.925076 -0.010759
# G1 2 -0.727028  0.545322
# G2 3  0.202716  2.209824

# %%
df.index.names= ['Groups','num']
df
# Out:
#                    A         B
# Groups num
# G1     1   -1.576038  1.230317
# G2     2    1.536682  0.438089
# G1     3   -0.752680  1.403316
# G2     1    0.925076 -0.010759
# G1     2   -0.727028  0.545322
# G2     3    0.202716  2.209824

# %%
df.loc['G1']
# Out:
#             A         B
# num
# 1   -1.576038  1.230317
# 3   -0.752680  1.403316
# 2   -0.727028  0.545322

# %%
df.xs(1,level='num')
# Out:
#                A         B
# Groups
# G1     -1.576038  1.230317
# G2      0.925076 -0.010759

# %%
df = pd.DataFrame(randn(5,4), index = 'A B C D E'.split(),columns= 'W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362
# E -0.043705  0.119848  0.242729  0.222944

# %%
df.W
# Out:
# A    1.932272
# B   -1.059230
# C    1.576314
# D   -1.512680
# E   -0.043705
# Name: W, dtype: float64

# %%
df['W']
# Out:
# A    1.932272
# B   -1.059230
# C    1.576314
# D   -1.512680
# E   -0.043705
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  1.932272 -1.266894
# B -1.059230  1.858233
# C  1.576314 -0.483304
# D -1.512680  0.506362
# E -0.043705  0.222944

# %%
df['new']=df['W']+df['Z']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  1.932272 -0.304529  0.546741 -1.266894  0.665377
# B -1.059230  0.056763 -1.182237  1.858233  0.799003
# C  1.576314 -0.342241  0.714673 -0.483304  1.093009
# D -1.512680  0.550642  0.259218  0.506362 -1.006319
# E -0.043705  0.119848  0.242729  0.222944  0.179239

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362
# E -0.043705  0.119848  0.242729  0.222944

# %%
df
# Out:
#           W         X         Y         Z       new
# A  1.932272 -0.304529  0.546741 -1.266894  0.665377
# B -1.059230  0.056763 -1.182237  1.858233  0.799003
# C  1.576314 -0.342241  0.714673 -0.483304  1.093009
# D -1.512680  0.550642  0.259218  0.506362 -1.006319
# E -0.043705  0.119848  0.242729  0.222944  0.179239

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362
# E -0.043705  0.119848  0.242729  0.222944

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362

# %%
df
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362
# E -0.043705  0.119848  0.242729  0.222944

# %%
df.drop('E',axis=0,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362

# %%
df.loc[['A','B'],['W','X']]
# Out:
#           W         X
# A  1.932272 -0.304529
# B -1.059230  0.056763

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True  False   True  False
# B  False   True  False   True
# C   True  False   True  False
# D  False   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  1.932272       NaN  0.546741       NaN
# B       NaN  0.056763       NaN  1.858233
# C  1.576314       NaN  0.714673       NaN
# D       NaN  0.550642  0.259218  0.506362

# %%
df[(df['W']>0)|(df['Y']>0.2)]
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362

# %%
df
# Out:
#           W         X         Y         Z
# A  1.932272 -0.304529  0.546741 -1.266894
# B -1.059230  0.056763 -1.182237  1.858233
# C  1.576314 -0.342241  0.714673 -0.483304
# D -1.512680  0.550642  0.259218  0.506362

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  1.932272 -0.304529  0.546741 -1.266894
# 1     B -1.059230  0.056763 -1.182237  1.858233
# 2     C  1.576314 -0.342241  0.714673 -0.483304
# 3     D -1.512680  0.550642  0.259218  0.506362

# %%
newind = 'AB AC AD AE'.split()

# %%
df['states'] = newind

# %%
df
# Out:
#           W         X         Y         Z states
# A  1.932272 -0.304529  0.546741 -1.266894     AB
# B -1.059230  0.056763 -1.182237  1.858233     AC
# C  1.576314 -0.342241  0.714673 -0.483304     AD
# D -1.512680  0.550642  0.259218  0.506362     AE

# %%
df.set_index('states', inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# states
# AB      1.932272 -0.304529  0.546741 -1.266894
# AC     -1.059230  0.056763 -1.182237  1.858233
# AD      1.576314 -0.342241  0.714673 -0.483304
# AE     -1.512680  0.550642  0.259218  0.506362

# %%
d = {'a':[1,2,np.nan],'b':[1,np.nan,np.nan],'c':[1,2,3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      a    b  c
# 0  1.0  1.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      a    b  c
# 0  1.0  1.0  1

# %%
df.dropna(axis=1)
# Out:
#    c
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      a    b  c
# 0  1.0  1.0  1
# 1  2.0  NaN  2

# %%
df.fillna('a')
# Out:
#    a  b  c
# 0  1  1  1
# 1  2  a  2
# 2  a  a  3

# %%
df['a'].fillna(df['a'].mean(),inplace=True)

# %%
df
# Out:
#      a    b  c
# 0  1.0  1.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
df.pivot_table(values = 'a', index ='b', columns='c')
# Out:
# c      1
# b
# 1.0  1.0

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2

# %%
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x,y,'b')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'r-')
axes1.set_title('Big')
axes2.plot(y,x,'b--')
axes2.set_title('small')
# Out:
# Text(0.5, 1.0, 'small')

# %%
fig, axes = plt.subplots(nrows = 1, ncols =2)

for ax in axes:
     ax.plot(x,y)
        
fig        
plt.tight_layout()

# %%
def my_sum(x,y):
    r = x+y
    return r

z=(lambda x,y: x+y)


def my_multiply(x,y,f):
    return f(x,y)

print(my_multiply(2,3,z))

print(my_sum(2,3))
# Out:
# 5
# 5

# %%
fig = plt.figure(figsize=(8,5))

# %%
fig,axes = plt.subplots(figsize=(13,2))

axes.plot(x, x**2,label='X2')

axes.plot(x,x**3, label= 'X3',lw=2,ls='--',marker='o')
axes.legend(loc=5)
axes.set_xlim([0,5])
axes.set_ylim([0,170])
# Out:
# (0, 170)

# %%
alpha = 0.7
phi_ext = 2 *np.pi *0.5 

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_m,phi_p)
Z = flux_qubit_potential(X,Y).T

# %%
#import matplotlib as plt
fig,ax = plt.subplots()
p = ax.pcolor(X/(2*np.pi),Y/(2*np.pi),Z, cmap=plt.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax = ax)

# %%
fig,ax = plt.subplots()
im = ax.imshow(Z,cmap=plt.cm.RdBu,vmin=abs(Z).min(), vmax=abs(Z).max(), extent =[0,1,0,1])
im.set_interpolation('bilinear')
cb = fig.colorbar(im,ax=ax)

# %%
fig,ax = plt.subplots()
cnt = ax.contour (Z, cmap = plt.cm.RdBu, vmin = abs(Z).min(),vmax=abs(Z).max(),extent=[0,1,0,1])

# %%
from mpl_toolkits. mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize =(14,6))
ax = fig.add_subplot(1,2,1,projection = '3d')
p = ax.plot_surface(X,Y,Z,rstride = 4, cstride=4,lw = 3 )

ax = fig.add_subplot(1,2,2, projection = '3d')
p = ax.plot_surface(X,Y,Z, cmap = plt.cm.coolwarm, rstride = 1, cstride = 1,antialiased=False)
cb = fig.colorbar(p, ax=ax, shrink =0.5)

# %%
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1,1,1, projection ='3d')
p= ax.plot_wireframe(X,Y,Z,rstride = 3, cstride =3)

# %%
fig = plt.figure(figsize =(8,6))
ax = fig.add_subplot(1,1,1, projection ='3d')
p = ax.plot_surface (X,Y,Z, rstride =4, cstride =4, alpha = 0.25)
cset = ax.contour(X,Y,Z, zdir = 'z', offset = - np.pi, cmap = plt.cm.coolwarm)
cset = ax.contour(X,Y,Z, zdir = 'x', offset = - np.pi,cmap = plt.cm.coolwarm)
cset = ax.contour(X,Y,Z, zdir = 'y', offset = 3* np.pi,cmap = plt.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde = False, bins = 30)

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind ='scatter')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])
sns.kdeplot(tips['total_bill'])
sns.distplot(tips['total_bill'])

# %%
sns.barplot(x = 'sex', y ='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='sex',data = tips)

# %%
sns.boxplot(x = 'day', y = 'total_bill', data=tips,hue='sex',palette='rainbow')

# %%
sns.violinplot(x='day',y='total_bill', data=tips, hue='sex', palette='rainbow', split=True)

# %%
sns.stripplot(x='day', y='total_bill', data = tips, jitter=False)

# %%
sns.stripplot(x='day', y='total_bill', data = tips,hue='sex',dodge=True)

# %%
sns.swarmplot(x='day', y='total_bill', data= tips, hue ='sex',dodge = True)

# %%
sns.swarmplot(x='day', y='total_bill', data= tips, hue ='sex',dodge = True, color='black')
sns.violinplot(x='day', y='total_bill', data= tips, hue ='sex',dodge = True)

# %%
sns.factorplot(x= 'day', y='total_bill', data=tips, kind='bar') # box, strip, swarm, violin
# Out:
# /Users/elham/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flights= sns.load_dataset('flights')

# %%
tc = tips.corr()

# %%
sns.heatmap(tc,annot=True,cmap = 'coolwarm')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
fp= flights.pivot(index='month', columns='year', values='passengers')

# %%
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidth=1)

# %%
sns.clustermap(fp, cmap='coolwarm',standard_scale = 1)

# %%
iris= sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g = sns.FacetGrid(tips,row = 'time', col='smoker',hue='sex')
g.map(plt.hist,'total_bill').add_legend()

# %%
g= sns.FacetGrid(tips,row='time',col='smoker',hue='sex')
g.map(plt.scatter,'total_bill','tip',cmap='coolwarm').add_legend()

# %%
g=sns.JointGrid(x='total_bill',y='tip', data=tips)
g.plot(sns.regplot, sns.distplot)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, col='day',hue='sex',aspect=0.6,size=10)
# Out:
# /Users/elham/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
